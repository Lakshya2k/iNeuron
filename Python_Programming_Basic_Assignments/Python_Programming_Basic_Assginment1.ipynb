# %% [markdown]
# ## Q1

# %%
def hello():
    print("Hello Python")

# %%
hello()
# Out:
# Hello Python

# %% [markdown]
# ## Q2

# %%
def add_div(x, y):
    return x+y, x/y

# %%
add_div(2,10)
# Out:
# (12, 0.2)

# %% [markdown]
# ## Q3

# %%
def area_triangle(x, y, z):
    s = (x+y+z)/2  # using heron's formula
    return (s*(s-x)*(s-y)*(s-z))**(1/2)

# %%
area_triangle(3, 4, 5)
# Out:
# 6.0

# %% [markdown]
# # Q4

# %%
def swap(x, y):
    x,y=y,x
    return x, y

# %%
x,y = 2,4

# %%
x,y = swap(x,y)

# %%
x,y
# Out:
# (4, 2)

# %% [markdown]
# ## Q5

# %%
import random
def gen_rand():
    return random.randint(0, 50) #generates random integer between 0 and 50 including both

# %%
gen_rand()
# Out:
# 27
